# %%
import pandas as pd
import numpy as np

# %%
customer_demographic=pd.read_excel("C:\\Users\\eiti mittal\\Downloads\\KPMG_VI_New_raw_data_update_final.xlsx",sheet_name='CustomerDemographic')

# %%
customer_demographic.sample(10)
# Out:
#       customer_id first_name  last_name  gender  \
# 3421         3422     Lucine     Virgin  Female
# 320           321  Christean     Finnes  Female
# 2398         2399    Devonne    McPolin  Female
# 88             89  Benedicto      Hoxey    Male
# 3728         3729     Armand     McNish    Male
# 272           273     Nevile    Abraham    Male
# 2257         2258      Cathy     Powter  Female
# 446           447   Brittany     Peasey  Female
# 3125         3126     Bondon     Deeley    Male
# 166           167   Nathalie  Tideswell  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 3421                                   38 1978-05-06
# 320                                    58 1973-09-15
# 2398                                   20 1980-06-11
# 88                                     74 1967-01-22
# 3728                                    6 1960-12-16
# 272                                    54 1963-04-22
# 2257                                   63 1974-03-21
# ...

# %%
customer_demographic.shape
# Out:
# (4000, 13)

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
customer_demographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
customer_demographic['default']
# Out:
# 0                                                      "'
# 1                            <script>alert('hi')</script>
# 2                                     2018-02-01 00:00:00
# 3       () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 4                                                     NIL
#                               ...
# 3995                                                 -100
# 3996                                             â¦testâ§
# 3997                                                  NaN
# 3998                               Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ
# 3999                                                  0/0
# Name: default, Length: 4000, dtype: object

# %%
customer_demographic=customer_demographic.drop('default',axis=1)
customer_demographic.sample(10)
# Out:
#       customer_id first_name    last_name  gender  \
# 991           992   Cordelia   Hawkeswood  Female
# 329           330       Port      Pancost    Male
# 239           240      Gavin        Fawks    Male
# 1062         1063   Terrence         Geck    Male
# 1591         1592     Thorin      Klagges    Male
# 1412         1413         Vi        Lauga  Female
# 398           399     Nickie      Neissen    Male
# 1786         1787       Tull  Godehard.sf    Male
# 997           998    Petunia       Dufton  Female
# 379           380    Teriann      Birdsey  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 991                                     6 1958-11-25
# 329                                    78 1959-06-03
# 239                                    49 1989-07-28
# 1062                                   22 1987-03-01
# 1591                                   21 1986-08-04
# 1412                                   47 1998-04-24
# ...

# %%
(customer_demographic[customer_demographic['job_industry_category'].isna() | customer_demographic['job_title'].isna()])[['job_title','job_industry_category']]
# Out:
#                  job_title job_industry_category
# 3                      NaN                    IT
# 4            Senior Editor                   NaN
# 5                      NaN                Retail
# 6                      NaN    Financial Services
# 7          Media Manager I                   NaN
# ...                    ...                   ...
# 3978                   NaN    Financial Services
# 3982      Graphic Designer                   NaN
# 3986                   NaN           Argiculture
# 3998                   NaN         Manufacturing
# 3999  Software Engineer IV                   NaN
#
# [1057 rows x 2 columns]

# %%
index=customer_demographic[customer_demographic.job_title.isnull() & customer_demographic.job_industry_category.isnull()].index
customer_demographic.drop(index,inplace=True)

# %%
customer_demographic['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
customer_demographic['gender'] = customer_demographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')
customer_demographic['gender'].value_counts()
# Out:
# Female         1978
# Male           1829
# Unspecified      88
# Name: gender, dtype: int64

# %%
customer_demographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        1950
# High Net Worth        988
# Affluent Customer     957
# Name: wealth_segment, dtype: int64

# %%
customer_demographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
customer_demographic['DOB']=pd.to_datetime(customer_demographic['DOB'])
customer_demographic['DOB']
# Out:
# 0      1953-10-12
# 1      1980-12-16
# 2      1954-01-20
# 3      1961-10-03
# 4      1977-05-13
#           ...
# 3995   1975-08-09
# 3996   2001-07-13
# 3997          NaT
# 3998   1973-10-24
# 3999   1991-11-05
# Name: DOB, Length: 3895, dtype: datetime64[ns]

# %%
#duplicate values
len(customer_demographic['customer_id'].unique())
# Out:
# 3895

# %%
age=[]
for i in customer_demographic['DOB']:
    age.append((pd.to_datetime('today').year-i.year))
customer_demographic['age']=age

# %%
customer_demographic
# Out:
#       customer_id      first_name  last_name       gender  \
# 0               1         Laraine  Medendorp       Female
# 1               2             Eli    Bockman         Male
# 2               3           Arlin     Dearle         Male
# 3               4          Talbot        NaN         Male
# 4               5  Sheila-kathryn     Calton       Female
# ...           ...             ...        ...          ...
# 3995         3996         Rosalia   Halgarth       Female
# 3996         3997          Blanch     Nisuis       Female
# 3997         3998          Sarene    Woolley  Unspecified
# 3998         3999       Patrizius        NaN         Male
# 3999         4000           Kippy    Oldland         Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# ...

# %%
customer_demographic.shape
# Out:
# (3895, 13)
